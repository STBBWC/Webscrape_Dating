# %%
# expanding upon chris work in okcupid
# https://www.wired.com/2014/01/how-to-hack-okcupid/
# no license

# %%
# !pip3 install pandas
# !pip3 install bs4
# !pip3 install numpy
# !pip3 install requests
# !pip3 install selenium
# !pip3 install html5lib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import ssl
# TODO refactor so we are not exposing ssl or other security data
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd
import bs4
import numpy as np
import requests
import selenium

# %% [markdown]
# from urllib.request import urlopen
# from bs4 import BeautifulSoup
# import re
#
# pages = set()
# def get_test_Links(pageUrl):
#     global pages
#     html = urlopen("http://en.wikipedia.org"+pageUrl)
#     bsObj = BeautifulSoup(html)
#     for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
#         if 'href' in link.attrs:
#             if link.attrs['href'] not in pages:
#                 #We have encountered a new page
#                 newPage = link.attrs['href']
#                 print(newPage)
#                 pages.add(newPage)
#                 get_test_Links(newPage)
#
# get_test_Links("")

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def get_test_Links(pageUrl):
    global pages
    html = urlopen("""https://beta.meetme.com/#home"""+pageUrl)
    bsObj = BeautifulSoup(html)
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                get_test_Links(newPage)

get_test_Links("")

# %%
url = """https://beta.meetme.com/#home"""
meetme_data_001 = pd.read_html(url)
meetme_data_001[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/v0/7gtj3bhx74z6w7kx78fhqlmm0000gn/T/ipykernel_22982/2846720573.py in <module>
#       1 url = """https://beta.meetme.com/#home"""
# ----> 2 meetme_data_001 = pd.read_html(url)
#       3 meetme_data_001[0]
#       4
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
# ...

# %%
website_login = 'https://beta.meetme.com/#home'

username = 'MEETME_USERNAME'

meetme_meet_data = pd.read_html("""https://beta.meetme.com/#meet""")
meetme_chat_data = pd.read_html("""https://beta.meetme.com/#chat""")

# %%
fake_user = ("Do me a favor and join me to my private",
				"Wanna cyber",
				"Hey you look sexy, come checkout my page",
				"I need to verify you, please check here to",
				"I need money, please click here to send me Cashapp",
				"What's up sexy I can't chat now but click here to",
				"CashApp",
             "onlyfans")

# %%
good_user =! fake_user

# %%
# scoring table for matches based on decision tree
def score_table(data_table):
	"""
	Returns a pretty-printed dataframe of scoring summary
	:param
	"""
	table = table.drop(len(table)-1) # Drop last row
	table = table.drop([0, 1]) # Drop first two rows
    table.columns = list(table.iloc[0])
    table = table.drop(2)
    table = table.reset_index(drop=True)
        return table

for data in meetme_data
	print(len(meetme_data))
